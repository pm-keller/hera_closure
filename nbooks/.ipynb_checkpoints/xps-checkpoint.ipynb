# %% [markdown]
# # H1C IDR3.2 Cross-Power Spectra
# Inspect cross-power spectra.

# %%
import h5py
import numpy as np
import scipy.stats as stats
import math

from itertools import product

import astropy.units as u

from ipywidgets import interact
import matplotlib.pyplot as plt
import matplotlib.markers
from matplotlib.lines import Line2D

import sys
sys.path.append("/users/pkeller/code/H1C_IDR3.2/")
from closurelib import dspec
from closurelib import plot

# %%
trclasses = ["EQ14", "EQ28"]
fields = ["A", "B", "C", "D", "E"]
pols = ["XX", "YY"]

data = dict()

for trclass in trclasses:
    data.update({trclass: dict()})
    
    for field in fields:
        path = f"/lustre/aoc/projects/hera/pkeller/data/H1C_IDR3.2/sample/{trclass}_F{field}_B2_XPS.h5"
        data[trclass].update({field: dict()})
        
        # load data
        with h5py.File(path, "r") as f:
            data[trclass][field].update({"weights XX": f["weights cross XX"][()]})
            data[trclass][field].update({"weights YY": f["weights cross YY"][()]})
            data[trclass][field].update({"XPS XX": f["XPS XX"][()]})
            data[trclass][field].update({"XPS YY": f["XPS YY"][()]})
            data[trclass][field].update({"XPS XX AVG": f["XPS XX AVG"][()]})
            data[trclass][field].update({"XPS YY AVG": f["XPS YY AVG"][()]})
            data[trclass][field].update({"ERR XX AVG": f["ERR XX AVG"][()]})
            data[trclass][field].update({"ERR YY AVG": f["ERR YY AVG"][()]})
            data[trclass][field].update({"Noise XX AVG": f["Noise XX AVG"][()]})
            data[trclass][field].update({"Noise YY AVG": f["Noise YY AVG"][()]})
            data[trclass][field].update({"XPS AVG": f["XPS AVG"][()]})
            data[trclass][field].update({"ERR AVG": f["ERR AVG"][()]})
            data[trclass][field].update({"Noise AVG": f["Noise AVG"][()]})
            delay = f["delay"][()]
            
k = dspec.get_k_parallel(delay * u.s, freq=161.585 * u.MHz).to(u.Mpc**-1).value
k_perp_14 = dspec.get_k_perpendicular(14.6 * u.m, 161.585 * u.MHz).to(u.Mpc ** -1).value
k_perp_28 = dspec.get_k_perpendicular(29.2 * u.m, 161.585 * u.MHz).to(u.Mpc ** -1).value

# %% [markdown]
# ## Plot Veff, (Inverse) Variance and Weights
# After mutliplication with Veff, the noise should even out as a function of LST. This cell allows to check that this is indeed what happens and that we are not overweighting any integrations.

# %%
field = "E"
eq = "14"

veff = np.loadtxt(f"/users/pkeller/code/H1C_IDR3.2/data/scaling_EQ{eq}_F{field}B2.dat")

with h5py.File(f"/lustre/aoc/projects/hera/pkeller/data/H1C_IDR3.2/sample/EQ{eq}_F{field}_B2_XPS.h5", "r") as f:
    w_xx = f["weights cross XX"][()]
    w_yy = f["weights cross YY"][()]
    
with h5py.File(f"/lustre/aoc/projects/hera/pkeller/data/H1C_IDR3.2/sample/EQ{eq}_F{field}_B2_AVG.h5", "r") as f:
    frq = f["FRQ"][()]
    lst = f["LST"][()]
    eicp1_xx = f["eicp XX (2)"][()]
    eicp1_yy = f["eicp YY (2)"][()]

noise_xx = np.nanmean(np.nanstd(eicp1_xx[1] - eicp1_xx[0], axis=-1), axis=0)
noise_yy = np.nanmean(np.nanstd(eicp1_yy[1] - eicp1_yy[0], axis=-1), axis=0)

plt.plot(veff[:, 0], label="Veff XX")
plt.plot(veff[:, 1], label="Veff YY")

plt.plot(noise_xx, label="Noise XX")
plt.plot(noise_yy, label="Noise YY")
plt.plot(noise_xx * np.sqrt(veff[:, 0]), label="Veff X Noise XX")
plt.plot(noise_yy * np.sqrt(veff[:, 1]), label="Veff X Noise YY")
#plt.plot(1 / (noise_xx * np.sqrt(veff[:, 0]))**2)
#plt.plot(1 / (noise_yy * np.sqrt(veff[:, 1]))**2)
plt.legend()
plt.yscale("log")
# Out:
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/numpy/lib/nanfunctions.py:1671: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   keepdims=keepdims)

# %% [markdown]
# ## Plot

# %%
import imp; imp.reload(plot); imp.reload(dspec)
fig, ax = plt.subplots(5, 2, figsize=(15, 18), sharex=True, sharey=True)
yticks =  np.hstack([-1 * 10 ** np.arange(3, 12, 2), 10 ** np.arange(3, 16, 2)])
fields = ["A", "B", "C", "D", "E"]

for i, field in enumerate(fields):
    ax[i, 0] = plot.xps_plot(data["EQ14"][field]["XPS AVG"], data["EQ14"][field]["ERR AVG"], freq=161.585 * u.MHz, onesided=True, ax=ax[i, 0], linthresh=1e3, tau_ax=(i==0), nsig=2)
    ax[i, 1] = plot.xps_plot(data["EQ28"][field]["XPS AVG"], data["EQ28"][field]["ERR AVG"], freq=161.585 * u.MHz, onesided=True, ax=ax[i, 1], linthresh=1e3, tau_ax=(i==0), nsig=2)
    ax[i, 0].text(2, 1e12, f"EQ14 Field {field}", fontsize=18)
    ax[i, 1].text(2, 1e12, f"EQ29 Field {field}", fontsize=18)

ax[-1, 0].set_xlabel(r"$|\kappa_{||}|$ (pseudo $h\,\mathrm{Mpc}^{-1}$)", fontsize=18)
ax[-1, 1].set_xlabel(r"$|\kappa_{||}|$ (pseudo $h\,\mathrm{Mpc}^{-1}$)", fontsize=18)

custom_markers = [Line2D([], [], color='k', marker='o', linestyle="None"),
                 Line2D([], [], mfc='None', mec='grey', marker='o', linestyle="None"),
                 Line2D([], [], mfc='k', mec='k', marker='s', alpha=0.1, linestyle="None"),
                 Line2D([0], [0], color="k", linestyle="dashed")]


plt.setp(ax, ylim=[-10**8, 10**15], yticks=yticks);
plt.tight_layout()

fig.subplots_adjust(wspace=0.05)
fig.subplots_adjust(left=0.08)
fig.text(0.02, 0.5, r"$\frac{2}{3}P_\bigtriangledown\left(\kappa_{||}\right)$ (pseudo $\mathrm{mK}^2h^{-3}\mathrm{Mpc}^3$)", fontsize=18, rotation=90., va="center", ha="center");
plt.legend(custom_markers, ['Real', 'Imaginary', '"2$\sigma$" Error Bars', 'Noise RMS ($|\kappa_{||}|>1.0$ pseudo $h\,\mathrm{Mpc}^{-1}$)'], bbox_to_anchor=(0.92, 0.01), bbox_transform=fig.transFigure, ncol=4, fontsize=16)
plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/xps.pdf", bbox_inches='tight')
# Out:
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# ...

# %%
fig, ax = plt.subplots(figsize=(7, 5))
ax = plot.xps_plot(data["EQ14"]["C"]["XPS AVG"], data["EQ14"]["C"]["ERR AVG"], freq=155.155 * u.MHz, onesided=True, ax=ax, linthresh=1e3, tau_ax=True, nsig=2)
ax.set_xlabel(r"$|\kappa_{||}|$ (pseudo $h\,\mathrm{Mpc}^{-1}$)", fontsize=18)
ax.set_ylabel(r"$\frac{2}{3}P_\bigtriangledown\left(\kappa_{||}\right)$ (pseudo $\mathrm{mK}^2h^{-3}\mathrm{Mpc}^3$)", fontsize=18)
ax.text(1.75, 1e12, f"EQ14 Field C", fontsize=14)
ax.text(1.75, 1e10, f"152.25-158.06 MHz", fontsize=14)
plt.setp(ax, ylim=[-10**8, 10**15], yticks=yticks);
plt.tight_layout()
plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/xps_rfi.pdf", bbox_inches='tight')
# Out:
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %% [markdown]
# ### EQ29

# %%
import imp; imp.reload(plot)
fig, ax = plt.subplots(2, 2, figsize=(15, 8), sharex=True, sharey=True)
yticks =  np.hstack([-1 * 10 ** np.arange(3, 12, 2), [0], 10 ** np.arange(3, 16, 2)])

for i, field in enumerate(fields):
    xps = data["EQ28"][field]["XPS AVG"]
    err = data["EQ28"][field]["ERR AVG"]

    ax[i // 2, i % 2] = plot.xps_plot(xps, err, freq=160.11 * u.MHz, onesided=True, ax=ax[i // 2, i % 2], linthresh=1e3, tau_ax=(i//2==0), nsig=2)
    if field == "E":
        ax[i // 2, i % 2].text(2, 1e12, r"EQ29 Field E$^*$", fontsize=18)
    else:
        ax[i // 2, i % 2].text(2, 1e12, f"EQ29 Field {field}", fontsize=18)

ax[1, 0].set_xlabel(r"$|\kappa_{||}|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)
ax[1, 1].set_xlabel(r"$|\kappa_{||}|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)

plt.legend(custom_markers, ['Real', 'Imaginary', '"2$\sigma$" Error Bars', 'Noise RMS ($|\kappa_{||}|>1.0$ pseudo $h\,\mathrm{Mpc}^{-1}$)'], bbox_to_anchor=(0.92, 0.02), bbox_transform=fig.transFigure, ncol=4, fontsize=16)

plt.setp(ax, ylim=[-10**9, 10**14], yticks=yticks);
plt.tight_layout()

fig.subplots_adjust(wspace=0.05)
fig.subplots_adjust(left=0.08)
fig.text(0.02, 0.5, r"$\frac{2}{3}P_\bigtriangledown\left(\kappa_{||}\right)$ (pseudo $\mathrm{mK}^2h^{-3}\mathrm{Mpc}^3$)", fontsize=18, rotation=90., va="center", ha="center");

plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/xps_EQ29.pdf", bbox_inches='tight')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-33cff8e7708f> in <module>
#       7     err = data["EQ28"][field]["ERR AVG"]
#       8
# ----> 9     ax[i // 2, i % 2] = plot.xps_plot(xps, err, freq=160.11 * u.MHz, onesided=True, ax=ax[i // 2, i % 2], linthresh=1e3, tau_ax=(i//2==0), nsig=2)
#      10     if field == "E":
#      11         ax[i // 2, i % 2].text(2, 1e12, r"EQ29 Field E$^*$", fontsize=18)
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %% [markdown]
# ## Triangle Plot

# %%
import imp; imp.reload(plot); imp.reload(dspec)
fig, ax = plt.subplots(2, 2, figsize=(15, 8), sharex=True, sharey=True)
yticks =  np.hstack([-1 * 10 ** np.arange(2, 12, 2), [0], 10 ** np.arange(2, 16, 2)])

for i, field in enumerate(fields):
    xps = data["EQ14"][field]["XPS AVG"]
    err = data["EQ14"][field]["ERR AVG"]
    
    ax[i // 2, i % 2] = plot.xps_plot(xps, err, freq=160.11 * u.MHz, onesided=True, ax=ax[i // 2, i % 2], linthresh=1e1, tau_ax=(i//2==0), cosmo=True, bls=29.3 * u.m, nsig=2)
    
    if field == "E":
        ax[i // 2, i % 2].text(1.5, 1e8, r"EQ14 Field E$^*$", fontsize=18)
    else:
        ax[i // 2, i % 2].text(1.5, 1e8, f"EQ14 Field {field}", fontsize=18)
        
ax[1, 0].set_xlabel(r"$|\kappa|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)
ax[1, 1].set_xlabel(r"$|\kappa|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)

plt.legend(custom_markers, ['Real', 'Imaginary', '"2$\sigma$" Error Bars', 'Noise RMS ($\kappa_{||}>1.0$ pseudo $h\,\mathrm{Mpc}^{-1}$)'], bbox_to_anchor=(0.92, 0.02), bbox_transform=fig.transFigure, ncol=4, fontsize=16)

plt.setp(ax, ylim=[0, 10**9], yticks=yticks);
plt.tight_layout()

fig.subplots_adjust(wspace=0.05)
fig.subplots_adjust(left=0.08)
fig.text(0.02, 0.5, r"$\frac{2}{3}\Delta^2_\bigtriangledown\left(\kappa_{||}\right)$ (pseudo $\mathrm{mK}^2$)", fontsize=18, rotation=90., va="center", ha="center");

# %%
import imp; imp.reload(plot); imp.reload(dspec)
fig, ax = plt.subplots(2, 2, figsize=(15, 8), sharex=True, sharey=True)
yticks =  np.hstack([-1 * 10 ** np.arange(2, 12, 2), [0], 10 ** np.arange(2, 16, 2)])

for i, field in enumerate(fields):
    xps = data["EQ28"][field]["XPS AVG"]
    err = data["EQ28"][field]["ERR AVG"]
    
    ax[i // 2, i % 2] = plot.xps_plot(xps, err, freq=160.11 * u.MHz, onesided=True, ax=ax[i // 2, i % 2], linthresh=1e1, tau_ax=(i//2==0), cosmo=True, bls=29.3 * u.m, nsig=2)
    
    if field == "E":
        ax[i // 2, i % 2].text(1.5, 1e8, r"EQ29 Field E$^*$", fontsize=18)
    else:
        ax[i // 2, i % 2].text(1.5, 1e8, f"EQ29 Field {field}", fontsize=18)
        
ax[1, 0].set_xlabel(r"$|\kappa|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)
ax[1, 1].set_xlabel(r"$|\kappa|$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)

plt.legend(custom_markers, ['Real', 'Imaginary', '"2$\sigma$" Error Bars', 'Noise RMS ($\kappa_{||}>2.0$ pseudo $h\,\mathrm{Mpc}^{-1}$)'], bbox_to_anchor=(0.92, 0.02), bbox_transform=fig.transFigure, ncol=4, fontsize=16)

plt.setp(ax, ylim=[0, 10**9], yticks=yticks);
plt.tight_layout()

fig.subplots_adjust(wspace=0.05)
fig.subplots_adjust(left=0.08)
fig.text(0.02, 0.5, r"$\frac{2}{3}\Delta^2_\bigtriangledown\left(\kappa_{||}\right)$ (pseudo $\mathrm{mK}^2$)", fontsize=18, rotation=90., va="center", ha="center");

# %%
import imp; imp.reload(plot); imp.reload(dspec)
fig, ax = plt.subplots(1, 1, figsize=(7, 5))
yticks =  np.hstack([0, 10 ** np.arange(3, 10, 1)])

xps = data["EQ14"]["C"]["XPS AVG"]
err = data["EQ14"]["C"]["ERR AVG"]

ax = plot.xps_plot(xps, err, freq=161.585 * u.MHz, onesided=True, ax=ax, linthresh=1e3, tau_ax=(i//2==0), cosmo=True, bls=14.6 * u.m, nsig=2)

ax.set_xlabel(r"$\kappa$ (pseudo $h\mathrm{Mpc}^{-1}$)", fontsize=18)

plt.setp(ax, xlim=[0.2, 2.0], ylim=[0, 10**7], yticks=yticks);
plt.tight_layout()

fig.subplots_adjust(wspace=0.05)
fig.subplots_adjust(left=0.12)
fig.text(0.02, 0.6, r"$\frac{2}{3}\Delta^2_\bigtriangledown\left(\kappa\right)$ (pseudo $\mathrm{mK}^2$)", fontsize=18, rotation=90., va="center", ha="center");
ax.text(1.4, 3*1e6, f"EQ14 Field C", fontsize=18)
ax.text(1.4, 1*1e6, f"z=7.8", fontsize=18)
plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/triangle_plot_EQ14_FC.pdf", bbox_inches='tight')
# Out:
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:796: ComplexWarning: Casting complex values to real discards the imaginary part
#   points = np.array(args, dtype=float).reshape(2, 2)
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/matplotlib/transforms.py:1959: ComplexWarning: Casting complex values to real discards the imaginary part
#   x, y = float(x), float(y)

# %% [markdown]
# ## Print Upper Limits

# %%
from scipy.special import erf, erfinv

xps = data["EQ14"]["C"]["XPS AVG"]
err = data["EQ14"]["C"]["ERR AVG"]
xps_0 = xps.real.copy()
xps_0[xps < 0] = 0
err = np.sqrt(np.sqrt(2) * xps_0 * err + err**2 * (1 - 1/np.sqrt(np.pi)))
kappa_14 = np.sqrt(k**2 + k_perp_14**2)
kappa_28 = np.sqrt(k**2 + k_perp_28**2)

N = len(kappa_14) // 2

kappa_14 = 0.5 * (np.abs(kappa_14) + np.flip(np.abs(kappa_14)))[N:]
kappa_28 = 0.5 * (np.abs(kappa_28) + np.flip(np.abs(kappa_28)))[N:]
xps = 0.5 * (xps + np.flip(xps))[N:]
#xps[np.where(xps < 0)] = 0
err = np.sqrt(0.5 * (err**2 + np.flip(err)**2))[N:]

for i, (bp, sig) in enumerate(zip(xps.real, err)):
    bp *= kappa_14[i]**3 / (2 * np.pi**2)
    sig *= kappa_14[i]**3 / (2 * np.pi**2)
    E = erf(bp / sig / np.sqrt(2))
    
    ul = sig * np.sqrt(2) * (erfinv(1 - (1 + E) * 0.045500263896 / 2) + bp / sig / np.sqrt(2))
    print("{:.3f} & ({:.2f})$^2$ & ({:.2f})$^2$".format(kappa_14[i], ul**0.5, sig**0.5))
# Out:
# 0.045 & (16273.45)$^2$ & (1947.03)$^2$
# 0.132 & (2630.00)$^2$ & (595.91)$^2$
# 0.219 & (292.16)$^2$ & (104.45)$^2$
# 0.307 & (170.91)$^2$ & (81.77)$^2$
# 0.394 & (207.38)$^2$ & (97.32)$^2$
# 0.482 & (inf)$^2$ & (94.08)$^2$
# 0.570 & (1642.69)$^2$ & (730.99)$^2$
# 0.657 & (1539.76)$^2$ & (676.45)$^2$
# 0.745 & (668.08)$^2$ & (359.18)$^2$
# 0.832 & (551.28)$^2$ & (257.38)$^2$
# 0.920 & (335.89)$^2$ & (188.06)$^2$
# 1.008 & (335.38)$^2$ & (195.36)$^2$
# 1.095 & (424.17)$^2$ & (242.35)$^2$
# 1.183 & (342.80)$^2$ & (221.04)$^2$
# 1.270 & (231.97)$^2$ & (176.60)$^2$
# 1.358 & (355.25)$^2$ & (215.32)$^2$
# 1.446 & (385.48)$^2$ & (255.66)$^2$
# 1.533 & (597.14)$^2$ & (341.02)$^2$
# 1.621 & (482.69)$^2$ & (320.77)$^2$
# 1.708 & (439.65)$^2$ & (303.59)$^2$
# 1.796 & (487.39)$^2$ & (327.36)$^2$
# 1.884 & (655.65)$^2$ & (423.94)$^2$
# 1.971 & (884.54)$^2$ & (522.50)$^2$
# 2.059 & (787.74)$^2$ & (493.90)$^2$
# 2.146 & (989.48)$^2$ & (608.79)$^2$
# 2.234 & (1177.45)$^2$ & (682.82)$^2$
# ...

# %% [markdown]
# ## Plot Cumulative Distribution Functions
# The cumulative distribution functions of the cross-power spectra at delays > 2us is expected to be noise dominated. Comparing the cumulative distribution functions of the real and imaginary parts of the data and noise power spectra respectrively allows to asses if there are any noise biases of excess variance in the data.

# %%
fig, ax = plt.subplots(2, 5, figsize=(10, 4))

for i, (trclass, field) in enumerate(product(trclasses, fields)):
    idx = np.where(np.abs(k) > 1)[0]
    d = data[trclass][field][f"XPS AVG"][..., idx]
    dr = np.sort(d.real)
    di = np.sort(d.imag)

    n = data[trclass][field][f"Noise AVG"][idx].reshape(-1)
    n = np.hstack([n.real, n.imag])
    n = np.sort(n)
    sig = np.std(n)
    
    if trclass == "EQ28":
        trclass = "EQ29"

    xrange = np.linspace(-4, 4, 1000)
    cdf_gauss = [0.5*(1 + math.erf(xrange[i]/np.sqrt(2))) for i in range(1000)]

    ax[i//5, i%5].vlines(0.0, 0, 1.0, linewidth=0.5, alpha=0.1)
    ax[i//5, i%5].plot(xrange, cdf_gauss, color="k", alpha=0.2)
    ax[i//5, i%5].plot(dr / sig, np.arange(len(dr)) / (len(dr)), color="r", linestyle="--")
    ax[i//5, i%5].plot(di / sig, np.arange(len(di)) / (len(di)), color="b", linestyle=":")
    ax[i//5, i%5].plot(n / sig, np.arange(len(n)) / (len(n)), color="m", linestyle="-.")
    ax[i//5, i%5].text(-3.5, 0.9, f"{trclass} F{field}")
    ax[i//5, i%5].minorticks_on()

fig.subplots_adjust(wspace=0.0, hspace=0.0)

custom_lines = [Line2D([0], [0], color="k", alpha=0.2),
                Line2D([0], [0], color="m", linestyle="-."),
                Line2D([0], [0], color="r", linestyle="--"),
                Line2D([0], [0], color="b", linestyle=":")]

plt.legend(custom_lines, ['Gaussian CDF', 'Differenced', 'Real', 'Imaginary'], bbox_to_anchor=(0.76, 0.0), bbox_transform=fig.transFigure, ncol=4)
plt.setp(ax, xlim=[-4, 4], ylim=[0, 1], xticks=[], yticks=[]);
plt.setp(ax[:, 0], yticks=np.arange(0.0, 1.0, 0.2));
plt.setp(ax[0, 0], yticks=np.arange(0.0, 1.2, 0.2));
plt.setp(ax[-1], xticks=np.arange(-4, 4));
plt.setp(ax[-1, -1], xticks=np.arange(-4, 5));
plt.setp(ax[:, 0], ylabel="CDF");
plt.setp(ax[-1], xlabel=r"$\sigma$");

plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/cdf.pdf", bbox_inches='tight')

# %% [markdown]
# ## Plot Histograms
# Just another way to plot the information above, which better illustrates biases and departures from normality.

# %%
fig, ax = plt.subplots(4, 4, figsize=(10, 9))

for i, (trclass, field, pol) in enumerate(product(trclasses, fields, pols)):
    idx = np.where(np.abs(k) > 1)[0]
    d = data[trclass][field][f"XPS {pol} AVG"][..., idx]
    dr = np.sort(d.real)
    di = np.sort(d.imag)
    hd = 1.7 * len(d)
    bin_d = np.arange(np.min(dr), np.max(dr), (np.max(dr)-np.min(dr)) / hd)

    n = data[trclass][field][f"Noise {pol} AVG"][idx].reshape(-1)
    n = np.hstack([n.real, n.imag])
    n = np.sort(n)
    hd = 1.7 * len(d)**(1/3)
    bin_n = np.arange(np.min(n), np.max(n), (np.max(n)-np.min(n)) / hd)
    sig = np.std(n)
    
    if trclass == "EQ28":
        trclass = "EQ29"
    if field == "E":
        field = r"E$^*$"

    xrange = np.linspace(-4, 4, 1000)
    pdf_gauss = stats.norm.pdf(xrange, 0, 1)
    
    ax[i//4, i%4].vlines(0.0, 0, 1.0, linewidth=0.5, alpha=0.1)
    ax[i//4, i%4].hist(n / sig, alpha=0.1, density=True, color="m")
    ax[i//4, i%4].hist(di / sig, alpha=0.1, density=True, color="b")
    ax[i//4, i%4].hist(dr / sig, alpha=0.1, density=True, color="r")
    ax[i//4, i%4].plot(xrange, pdf_gauss, alpha=1, color="grey")
    ax[i//4, i%4].text(-3.5, 0.9, f"{trclass} F{field} {pol}")
    ax[i//4, i%4].minorticks_on()

fig.subplots_adjust(wspace=0.0, hspace=0.0)


plt.setp(ax, xlim=[-4, 4], ylim=[0, 1], xticks=[], yticks=[]);
plt.setp(ax[:, 0], yticks=np.arange(0.0, 1.0, 0.2));
plt.setp(ax[0, 0], yticks=np.arange(0.0, 1.2, 0.2));
plt.setp(ax[-1], xticks=np.arange(-4, 4));
plt.setp(ax[-1, -1], xticks=np.arange(-4, 5));
plt.setp(ax[:, 0], ylabel="PDF");
plt.setp(ax[-1], xlabel=r"$\sigma$");

#plt.savefig("/users/pkeller/code/H1C_IDR3.2/plots/cdf.pdf", bbox_inches='tight')

# %% [markdown]
# ## Statistical Tests
# We use two statistical tests to our data: (1) Shapiro-Wilk test for normality and (2) Kolmogorov-Smirnov test. The first test draws on the observation that the noise is well matched to a Gaussian distribution. The second test is to see if how well the distribution of the power spectra at high delays matches the noise distribution. The K-S test is nonparametric and therefore makes no assumptions about the distributions of the data and the noise. To be exact, we are testing the Null-Hypothesis that the two distributions under comparison are equal. We reject the Null-Hypothesis based on a chosen significance threshold of 0.05. A p-value p<0.05 means we reject the null-hypothesis whereas p>0.05 means we can't reject the null-hypothesis. A p-value of 0.05 roughly corresponds to a 5 sigma rejection level in the case of a Gaussian distriubution.

# %%
for i, (trclass, field, pol) in enumerate(product(trclasses, fields, pols)):
    idx = np.where(np.abs(k) > 1)[0]
    d = data[trclass][field][f"XPS {pol} AVG"][..., idx]
    n = data[trclass][field][f"Noise {pol} AVG"][idx].reshape(-1)
    n = np.hstack([n.real, n.imag])
    shapiro = stats.shapiro(n / n.std())
    ad_real = stats.anderson_ksamp([d.real, n])
    ad_imag = stats.anderson_ksamp([d.imag, n])
        
    if shapiro[1]<0.05:
        color1 = "\cellcolor{myred}"
    else:
        color1 = "\cellcolor{mygreen}"
    
    if ad_real[0]>ad_real[1][2]:
        color2 = "\cellcolor{myred}"
    else:
        color2 = "\cellcolor{mygreen}"
        
    if ad_imag[0]>ad_imag[1][2]:
        color3 = "\cellcolor{myred}"
    else:
        color3 = "\cellcolor{mygreen}"
        
    # print LaTex table
    print("{} Field {} {} & {} {:.3f} & {} {:.3f} & {} {} & {} {:.3f} & {} {} & {} {:.3f} & {} {} \\\\".format(trclass, field, pol, color1, shapiro[0], color1, shapiro[1], color1, shapiro[1]<0.05, color2, ad_real[0], color2, ad_real[0]>ad_real[1][2], color3, ad_imag[0], color3, ad_imag[0]>ad_imag[1][2]))
# Out:
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: p-value capped: true value larger than 0.25
#   import sys
# /lustre/aoc/projects/hera/pkeller/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: UserWarning: p-value capped: true value larger than 0.25
# EQ14 Field A XX & \cellcolor{mygreen} 0.994 & \cellcolor{mygreen} 0.450 & \cellcolor{mygreen} False & \cellcolor{mygreen} -1.087 & \cellcolor{mygreen} False & \cellcolor{mygreen} 0.656 & \cellcolor{mygreen} False \\
# EQ14 Field A YY & \cellcolor{myred} 0.988 & \cellcolor{myred} 0.029 & \cellcolor{myred} True & \cellcolor{mygreen} -0.841 & \cellcolor{mygreen} False & \cellcolor{mygreen} -0.520 & \cellcolor{mygreen} False \\
# EQ14 Field B XX & \cellcolor{mygreen} 0.992 & \cellcolor{mygreen} 0.173 & \cellcolor{mygreen} False & \cellcolor{mygreen} 0.399 & \cellcolor{mygreen} False & \cellcolor{mygreen} -0.651 & \cellcolor{mygreen} False \\
# ...

# %%
for i, (trclass, field) in enumerate(product(trclasses, fields)):
    idx = np.where(np.abs(k) > 1)[0]
    d = data[trclass][field][f"XPS AVG"][..., idx]
    n = data[trclass][field][f"Noise AVG"][idx].reshape(-1)
    n = np.hstack([n.real, n.imag])
    shapiro = stats.shapiro(n / n.std())
    ad_real = stats.anderson_ksamp([d.real, n])
    ad_imag = stats.anderson_ksamp([d.imag, n])
        
    if shapiro[1]<0.05:
        color1 = "\cellcolor{myred}"
    else:
        color1 = "\cellcolor{mygreen}"
    
    if ad_real[0]>ad_real[1][2]:
        color2 = "\cellcolor{myred}"
    else:
        color2 = "\cellcolor{mygreen}"
        
    if ad_imag[0]>ad_imag[1][2]:
        color3 = "\cellcolor{myred}"
    else:
        color3 = "\cellcolor{mygreen}"
        
    # print LaTex table
    print("{} Field {} & {} {:.3f} & {} {:.3f} & {} {} & {} {:.3f} & {} {} & {} {:.3f} & {} {} \\\\".format(trclass, field, color1, shapiro[0], color1, shapiro[1], color1, shapiro[1]<0.05, color2, ad_real[0], color2, ad_real[0]>ad_real[1][2], color3, ad_imag[0], color3, ad_imag[0]>ad_imag[1][2]))
# Out:
# EQ14 Field A & \cellcolor{mygreen} 0.996 & \cellcolor{mygreen} 0.665 & \cellcolor{mygreen} False & \cellcolor{mygreen} -0.657 & \cellcolor{mygreen} False & \cellcolor{mygreen} -0.615 & \cellcolor{mygreen} False \\
# EQ14 Field B & \cellcolor{mygreen} 0.994 & \cellcolor{mygreen} 0.457 & \cellcolor{mygreen} False & \cellcolor{myred} 6.831 & \cellcolor{myred} True & \cellcolor{mygreen} -0.937 & \cellcolor{mygreen} False \\
# EQ14 Field C & \cellcolor{mygreen} 0.997 & \cellcolor{mygreen} 0.905 & \cellcolor{mygreen} False & \cellcolor{myred} 4.477 & \cellcolor{myred} True & \cellcolor{mygreen} 0.002 & \cellcolor{mygreen} False \\
# EQ14 Field D & \cellcolor{mygreen} 0.994 & \cellcolor{mygreen} 0.391 & \cellcolor{mygreen} False & \cellcolor{myred} 6.705 & \cellcolor{myred} True & \cellcolor{mygreen} -0.543 & \cellcolor{mygreen} False \\
# ...
